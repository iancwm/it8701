# %% [markdown]
# # Singapore Telecommunications Overview
#
# ## Introduction
#
# This Jupyter notebook was prepared according to the requirements of the CA2 submission for the **IT8701 - Introduction to Programming for Data Science** unit, which are hereby appended:
#
# 1.	You must use at least **three datasets** from http://data.gov.sg. The topic is unrestricted, i.e. you can mix the three datasets from any topic.  You are also permitted to use additional datasets from other websites, e.g. World Bank Data (http://databank.worldbank.org/data/home.aspx)
#
# 2.	Your Python programs must include features to allow the user to store and retrieve the datasets in a **relational database** such as `mySQL` or a `NoSQL` database like `MongoDB` on **at least one** of the datasets.
#
# 3.	You must use the `pandas` package on **at least one** of the datasets
#
# 4.	For each dataset you use, you must write a Python program that uses a **data visualization package** such as `matplotlib`, `seaborn`, `bokeh`, `pygal` etc to produce useful graphs / charts that explain the data.
#
# Your submission should contain at least four the following graphs / chart types:
#
# - A bar chart
# - A pie chart
# - A line chart
# - A histogram
# - A scatterplot
# - A boxplot
#
# ## Outline of the Analysis
# Singapore has a reputation of being technology-driven. From initiatives like **data.gov.sg** and **Smart Nation**, to institutions like the **IMDA**, it's not hard to see why.
#
# In this Jupyter Notebook, we try to quantify this reputation and take a look at the relevant datasets which we categorise under three themes
#
# 1. Telecommunications service standards
# 2. Singapore mobile broadband trends
# 3. Singapore fixed broadband trends
#
# ## Key Libraries Used
# We will use the following libraries extensively:
#
# - `pandas`
# - `matplotlib`
# - `seaborn`
# - `plotly_express`
# - `mysql-connector`
#
# # Preamble
# We have set up a `MySQL` database named `ca2ian` with access as `root`. We will now set up the notebook and begin loading the data into `pandas`.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import mysql.connector

# %% [markdown]
# ## seaborn colour palette
# Time to set our `seaborn` color palette. Let's choose from:
#
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
current_palette = sns.color_palette('nipy_spectral')
current_palette_ext = sns.color_palette('nipy_spectral',12)
# current_palette = sns.color_palette('nipy_spectral')
sns.palplot(current_palette)
sns.palplot(current_palette_ext)

# %%
sns.set_palette(current_palette)

# %% [markdown]
# ## seaborn styles

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ## Other setup
#
# - seaborn style
# - figsize

# %%
pd.options.display.max_columns = 40
pd.options.display.notebook_repr_html = True
pd.options.display.html.table_schema = True

# %% [markdown]
# ## rcParams setup
# Make the visualizations more palatable

# %%
mpl.rcParams['font.sans-serif']='Helvetica'
mpl.rcParams['font.size']='9.0'
mpl.rcParams['figure.figsize']='10, 6'
mpl.rcParams['figure.dpi']='100'

# %%
data1 = 'Communications/3g-public-cellular-mobile-telephone-services-nation-wide-service-coverage.csv'
data2 = 'Communications/3g-public-cellular-mobile-telephone-services-average-drop-call-rate.csv'
data3 = 'Communications/mobile-data-usage.csv'
data4 = 'Communications/mobile-penetration-rate.csv'
data5 = 'Communications/residential-wired-broadband-subscriptions-by-type-monthly.csv'
data6 = 'Communications/total-internet-dial-up.csv'
data7 = 'Communications/fixed-broadband-plans-and-prices.csv'
worldbankdata1 = 'API_IT.CEL.SETS.P2_DS2_en_csv_v2_54223.csv'

# %% [markdown]
# # Theme 1 - Telecommunications service standards
#
# We take a look at how well covered Singapore is by its main telecommunications providers, and how reliable their service is. The data consists of a timeseries of percentages representing coverage and drop rates for 3G services.
#
# ## Datasets used
#
# 1. **Dataset 1** - `3g-public-cellular-mobile-telephone-services-nation-wide-service-coverage.csv`
# 2. **Dataset 2** - `3g-public-cellular-mobile-telephone-services-average-drop-call-rate.csv`
#
# ## Methodology
# The data sets are one variable time series data with categories.
#
# We use lineplots on both datasets and a boxplot to determine the variability in performance.
#
# ## Set up
# Load the data using `pandas.read_csv` and print the `info()` to get a sense of the data

# %%
df1 = pd.read_csv(data1)
df2 = pd.read_csv(data2)
for i in (df1,df2):
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 3 columns):
# month               117 non-null object
# telco               117 non-null object
# service_coverage    117 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 2.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 3 columns):
# month             117 non-null object
# telco             117 non-null object
# drop_call_rate    117 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 2.9+ KB
# None

# %% [markdown]
# **Dataset 1**
#
# We use `seaborn` to generate a `lineplot`, split by `telco`.

# %%
fig,ax=plt.subplots()
sns.lineplot(data=df1,
             x='month',
             y='service_coverage',
             hue='telco').set_title('Singapore Telcos Nationwide Service Coverage (%)')
plt.xlabel('Month')
plt.ylabel('Service Coverage (%)')
plt.xticks(rotation='vertical')
month=df1['month'].iloc[len(df1)-1]
most_recent=df1[df1['month']==month]
for i in range(len(most_recent)):
    ax.text(month, 
            most_recent['service_coverage'].iloc[i], 
            "{}%".format(str(most_recent['service_coverage'].iloc[i])), 
            color=current_palette[i], 
            ha='left')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# We can plot a `boxplot` to visualize the series' distribution

# %%
sns.boxplot(data=df1,
            x='telco',
            y='service_coverage',
            notch=True).set_title('Singapore Telcos Nationwide Service Coverage Boxplot')
plt.xlabel('Telco Provider')
plt.ylabel('Service Coverage (%)')
plt.show()

# %% [markdown]
# **Dataset 2**
#
# We give the same treatment to Dataset 2, calling `seaborn` to generate a `lineplot` by `telco`.

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df2,
             x='month',
             y='drop_call_rate',
             hue='telco').set_title('Singapore Telco Average 3G Call Drop Rate (%)')
plt.xlabel('Month')
plt.ylabel('Call Drop Rate (%)')
plt.xticks(rotation='vertical')

# Labels
month=df2['month'].iloc[len(df2)-1]
most_recent=df2[df2['month']==month]
for i in range(len(most_recent)):
    ax.text(month, 
            most_recent['drop_call_rate'].iloc[i], 
            "{}%".format(str(most_recent['drop_call_rate'].iloc[i])), 
            color=current_palette[i], 
            ha='left')
plt.show()
# change tick size

# %% [markdown]
# Generating `boxplot` for the three telcos.

# %%
sns.boxplot(data=df2,x='telco',y='drop_call_rate').set_title('Singapore Telco Average 3G Call Drop Rate Boxplot')
plt.xlabel('Telco Provider')
plt.ylabel('Drop Call Rate (%)')
plt.show()

# %%
df2_pie = df2[-3:].set_index('telco')['drop_call_rate']
df2_pie_percentage = df2_pie / df2_pie.sum()
df2_pie_percentage.plot(kind='pie',
                        autopct='%1.1f%%',
                        textprops={'color':'white',
                                   'size':'large'}).set_title('June 2016 3G Call Drop Share by Telco')
plt.show()

# %% [markdown]
# ## Analysis
#
# In terms of island-wide coverage (Dataset 1), it would seem M1 is the most erratic from a visual comparison of the boxplot we generated, and we may think it justified to deem it the worst of the three telcos.
#
# However, bear in mind on an absolute scale, all three major telcos are doing a good job, with coverage well-above 95% across the board.
#
# Furthermore, from Dataset 2, while we can see that the telcos have lowered the drop call rate on average, we can see that Singtel is responsible for most of 3G call drops as of June 2016, with its `drop_call_rate` the highest of the three.
#
# So, while Singtel wins in terms of sheer coverage, the service is marginally less reliable.

# %% [markdown]
# ----
#
# # Theme 2 - Singapore mobile broadband usage trends
#
# *How much* of the population has **access** to mobile data, and how does this compare to the rest of the world?
#
# Also, just *how much* mobile data is Singapore **consuming**?
#
# ## Datasets used
#
# 3. **Dataset 3** - `mobile-data-usage.csv`
# 4. **Dataset 4** - `mobile-penetration-rate.csv`
# 5. **World Bank Dataset 1** - `API_IT.CEL.SETS.P2_DS2_en_csv_v2_54223`
#
# ## Methodology
# Simple one variable time-series data warrants a lineplot.
#
# ## Set up
# Load data with `pandas.read_csv`

# %%
df3 = pd.read_csv(data3)
df4 = pd.read_csv(data4)
worldbankdf1 = pd.read_csv(worldbankdata1,skiprows=4,header=0)
for i in (df3,df4,worldbankdf1):
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
# quarter                  56 non-null object
# volume_of_mobile_data    56 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 2 columns):
# month                      260 non-null object
# mobile_penetration_rate    260 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 64 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              246 non-null float64
# 1961              0 non-null float64
# 1962              0 non-null float64
# 1963              0 non-null float64
# 1964              0 non-null float64
# 1965              246 non-null float64
# 1966              0 non-null float64
# 1967              0 non-null float64
# 1968              0 non-null float64
# 1969              0 non-null float64
# 1970              246 non-null float64
# 1971              0 non-null float64
# 1972              0 non-null float64
# 1973              0 non-null float64
# 1974              0 non-null float64
# 1975              246 non-null float64
# 1976              246 non-null float64
# 1977              246 non-null float64
# 1978              246 non-null float64
# 1979              246 non-null float64
# 1980              246 non-null float64
# 1981              244 non-null float64
# 1982              244 non-null float64
# 1983              243 non-null float64
# 1984              242 non-null float64
# 1985              241 non-null float64
# 1986              242 non-null float64
# 1987              240 non-null float64
# 1988              241 non-null float64
# 1989              239 non-null float64
# 1990              253 non-null float64
# 1991              242 non-null float64
# 1992              244 non-null float64
# 1993              244 non-null float64
# 1994              244 non-null float64
# 1995              246 non-null float64
# 1996              247 non-null float64
# 1997              246 non-null float64
# 1998              248 non-null float64
# 1999              249 non-null float64
# 2000              250 non-null float64
# 2001              250 non-null float64
# 2002              252 non-null float64
# 2003              252 non-null float64
# 2004              253 non-null float64
# 2005              250 non-null float64
# 2006              247 non-null float64
# 2007              250 non-null float64
# 2008              248 non-null float64
# 2009              250 non-null float64
# 2010              253 non-null float64
# 2011              249 non-null float64
# 2012              253 non-null float64
# 2013              250 non-null float64
# 2014              251 non-null float64
# 2015              253 non-null float64
# 2016              247 non-null float64
# 2017              248 non-null float64
# 2018              0 non-null float64
# Unnamed: 63       0 non-null float64
# dtypes: float64(60), object(4)
# memory usage: 132.1+ KB
# None

# %%
fig,ax=plt.subplots()
sns.barplot(data=df3[14:], # select more recent time periods
            x='quarter',
            y='volume_of_mobile_data',
            color=current_palette[0],
            edgecolor='None').set_title('Singapore Volume of Mobile Data (PB)')
# Plot value labels 5% above the height of each bar
for i, v in enumerate(df3['volume_of_mobile_data'][14:].values.round(1)):
    ax.text(i, 
            v*1.05, 
            str(v), 
            color=current_palette[0], 
            ha='center')
plt.xlabel('Quarter')
plt.ylabel('Mobile Data Usage (PB)')
plt.xticks(rotation='vertical')
plt.show()
# change tick size

# %%
fig,ax=plt.subplots()
df3_growth = pd.DataFrame(df3['volume_of_mobile_data'].diff()/df3['volume_of_mobile_data'][1:]*100).set_index(df3['quarter'])
sns.lineplot(data=df3_growth).set_title('% Growth in Mobile Data Usage (Quarterly)')

# Labels
month=df3_growth.index[-1]
ax.text(month,
        df3_growth.iloc[len(df3_growth)-1]['volume_of_mobile_data'],
        str("{}%".format(df3_growth.iloc[len(df3_growth)-1]['volume_of_mobile_data'].round(1))),
        color=current_palette[0],
        fontsize=10,
        ha='left')
plt.xlabel('Quarter')
plt.ylabel('Growth in Mobile Data Usage (%)')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(15,6))
fig,ax=plt.subplots()
sns.lineplot(data=df4,x='month',y='mobile_penetration_rate').set_title('Singapore mobile penetration (%)')
# Labels
month=df4['month'].iloc[-1]
ax.text(month,
        df4.iloc[len(df4)-1]['mobile_penetration_rate'],
        str("{}%".format(df4.iloc[len(df4)-1]['mobile_penetration_rate'].round(1))),
        color=current_palette[0],
        fontsize=10,
        ha='left')
plt.tick_params(axis='x',which='major',labelsize=6)
plt.xlabel('Month')
plt.ylabel('Mobile Penetration (%)')
plt.xticks(rotation=30,fontsize=6)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Let's take a look at global mobile penetration via the dataset from **World Bank Data**

# %%
worldbankdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 64 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              246 non-null float64
# 1961              0 non-null float64
# 1962              0 non-null float64
# 1963              0 non-null float64
# 1964              0 non-null float64
# 1965              246 non-null float64
# 1966              0 non-null float64
# 1967              0 non-null float64
# 1968              0 non-null float64
# 1969              0 non-null float64
# 1970              246 non-null float64
# 1971              0 non-null float64
# 1972              0 non-null float64
# 1973              0 non-null float64
# 1974              0 non-null float64
# 1975              246 non-null float64
# 1976              246 non-null float64
# 1977              246 non-null float64
# 1978              246 non-null float64
# 1979              246 non-null float64
# 1980              246 non-null float64
# 1981              244 non-null float64
# 1982              244 non-null float64
# 1983              243 non-null float64
# 1984              242 non-null float64
# 1985              241 non-null float64
# 1986              242 non-null float64
# 1987              240 non-null float64
# 1988              241 non-null float64
# 1989              239 non-null float64
# 1990              253 non-null float64
# 1991              242 non-null float64
# 1992              244 non-null float64
# 1993              244 non-null float64
# 1994              244 non-null float64
# 1995              246 non-null float64
# 1996              247 non-null float64
# 1997              246 non-null float64
# 1998              248 non-null float64
# 1999              249 non-null float64
# 2000              250 non-null float64
# 2001              250 non-null float64
# 2002              252 non-null float64
# 2003              252 non-null float64
# 2004              253 non-null float64
# 2005              250 non-null float64
# 2006              247 non-null float64
# 2007              250 non-null float64
# 2008              248 non-null float64
# 2009              250 non-null float64
# 2010              253 non-null float64
# 2011              249 non-null float64
# 2012              253 non-null float64
# 2013              250 non-null float64
# 2014              251 non-null float64
# 2015              253 non-null float64
# 2016              247 non-null float64
# 2017              248 non-null float64
# 2018              0 non-null float64
# Unnamed: 63       0 non-null float64
# dtypes: float64(60), object(4)
# memory usage: 132.1+ KB

# %%
# Transpose the dataset, set column labels to the original index which is now in the dataframe, and then drop them
worldbankdf1_cleaned = worldbankdf1.drop(labels=['Country Code','Indicator Name','Indicator Code'],axis=1).T
worldbankdf1_cleaned.columns = worldbankdf1_cleaned.iloc[0]
# The dataframe is now made of objects, so we need to cast them to numerical data for analysis
# 1977              0.000000   0.000000   0.000000
# 1978              0.000000   0.000000   0.000000
# 1979              0.000000   0.000000   0.000000
# 1980              0.000000   0.000000   0.000000
# 1981              0.000000   0.000000   0.000000
# 1982              0.000000   0.000000   0.000000
# 1983              0.000000   0.000000   0.000000
# 1984              0.000000   0.000000   0.000000
# 1985              0.000000   0.000000   0.000000
# 1986              0.000000   0.000000   0.000000
# 1987              0.000000   0.000000   0.000000
# 1988              0.000000   0.000000   0.000000
# 1989              0.010833   0.000000   0.000000
# 1990              0.015122   0.000000   0.000000
# 1991              0.018471   0.000000   0.000000
# 1992              0.031783   0.000000   0.000000
# 1993              0.099255   0.000000   0.000000
# 1994              0.824864   0.000000   0.000000
# 1995              1.271141   0.016931   0.000000
# 1996              2.221522   0.028964   0.000000
# 1997              4.205509   0.047069   0.048967
# 1998              7.520489   0.083013   0.159754
# 1999             11.513851   0.275301   1.442243
# 2000             18.235966   0.938666   2.179967
# 2001             23.255360   1.119721   2.539203
# 2002             29.136966   1.250781   2.710118
# 2003             35.383946   2.109966   2.878376
# 2004             43.191969   3.958098   3.331987
# 2005             69.560734   7.878748   5.000838
# 2006             80.345054  13.431867   6.470045
# 2007             84.791321  20.737320   9.194766
# 2008             89.264232  27.051392  12.204335
# 2009             91.103109  32.747811  28.898095
# 2010             97.649179  39.328361  54.662975
# 2011            122.456361  57.235841  63.948179
# 2012            129.049634  71.596742  85.745933
# 2013            142.958900  68.604612  90.558714
# 2014            145.363687  64.751833  76.556585
# 2015            159.156344  71.784495  80.858499
# 2016            147.125206  72.429338  79.743884
# 2017            156.033229  78.614934  85.252183
# 2018            156.033229  78.614934  85.252183
#
# [59 rows x 264 columns]

# %%
mobile_penetration_g10_singapore = worldbankdf1_cleaned.loc['2017'][['Singapore',
                                                                     'Belgium',
                                                                     'Canada',
                                                                     'France',
                                                                     'Italy',
                                                                     'Japan',
                                                                     'Netherlands',
                                                                     'Sweden',
                                                                     'Switzerland',
                                                                     'United Kingdom',
                                                                     'United States']].sort_values()

fig, ax = plt.subplots()
sns.barplot(x=mobile_penetration_g10_singapore.index,
            y=mobile_penetration_g10_singapore,
            palette=current_palette_ext,
            edgecolor='None').set_title('Singapore has higher mobile penetration than the G10 economies (2017)')
# Draw labels with y-offset of 3, and colors iterated according to colour of the series
for i, v in enumerate(mobile_penetration_g10_singapore.values.round(1)):
    ax.text(i, 
            v+3, 
            str(v), 
            color=current_palette_ext[i], 
            ha='center')
plt.ylabel('Mobile Penetration %')
plt.xlabel('Country')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Analysis
#
# From the data we have, its plain to see Singapore residents are very much 'plugged in'. Mobile penetration stands at over 100%, which suggests people own multiple devices that are connected to the internet.
#
# Singapore's mobile penetration surpasses even the G10 countries.
#
# Mobile data consumption is also growing exponentially, a sign of an increasingly interconnected society and comfort with technology.

# %% [markdown]
# ----
#
# # Theme 3 - Singapore fixed broadband usage habits
#
# We take a look at trends in fixed broadband subscription, with respect to service type, prices and speed.
#
# ## Datasets used
#
# 5. **Dataset 5** - `residential-wired-broadband-subscriptions-by-type-monthly.csv`
# 6. **Dataset 6** - `total-internet-dial-up.csv`
# 7. **Dataset 7** - `fixed-broadband-plans-and-prices.csv`
#
# ## Methodology
# Dataset 5 and 6 are simple one-variable time series, warranting a lineplot.
#
# Dataset 7 is substantial and has multiple categories and datatypes. We will use `mysql-connector` to upload the data into a `MySQL` database for further analysis.

# %%
df5 = pd.read_csv(data5)
df6 = pd.read_csv(data6)
df7 = pd.read_csv(data7)
for i in [df5, df6, df7]:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 3 columns):
# month                    334 non-null object
# broadband_connections    334 non-null object
# no_of_subscriptions      334 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 8.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 2 columns):
# month                    261 non-null object
# total_internet_dialup    261 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 4.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2433 entries, 0 to 2432
# Data columns (total 10 columns):
# month                 2433 non-null object
# date_of_retrieval_    2433 non-null object
# operator              2433 non-null object
# plan                  2433 non-null object
# max_speed             2433 non-null object
# plan_type             2433 non-null object
# connection_type       2433 non-null object
# contract_duration     2433 non-null object
# price_of_plan         2433 non-null object
# price_per_mbps        2433 non-null object
# dtypes: object(10)
# memory usage: 190.2+ KB
# None

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.lineplot(data=df5,
             x='month',
             y='no_of_subscriptions',
             hue='broadband_connections').set_title('Singapore Residential Wired Broadband Subscriptions By Type, Monthly')
plt.xlabel('Month')
plt.ylabel('No. Subcriptions')
plt.xticks(rotation=30,size=6)

# Labels
month=df5['month'].iloc[len(df5)-1]
most_recent=df5[df5['month']==month]
for i in range(len(most_recent)):
    ax.text(month, 
            most_recent['no_of_subscriptions'].iloc[i], 
            str(most_recent['no_of_subscriptions'].iloc[i]), 
            color=current_palette[i], 
            ha='left')
plt.show()
# change tick size

# %%
fig,ax = plt.subplots(figsize=(15,6))

sns.lineplot(data=df6.iloc[101:], # select more recent periods
             x='month',
             y='total_internet_dialup').set_title('Singapore Dialup Connections')
plt.xlabel('Month')
plt.xticks(rotation=30,size=6)
plt.ylabel('No. Subcriptions')
# Labels
month=df6['month'].iloc[len(df6)-1]
ax.text(month,
        df6.loc[len(df6)-1]['total_internet_dialup'],
        str(df6.loc[len(df6)-1]['total_internet_dialup']),
        color=current_palette[0],
        fontsize=10,
        ha='left')
plt.show()
# change tick size

# %%
df7 = df7.replace('na',np.NaN)
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2433 entries, 0 to 2432
# Data columns (total 10 columns):
# month                 2433 non-null object
# date_of_retrieval_    2433 non-null object
# operator              2433 non-null object
# plan                  2433 non-null object
# max_speed             2243 non-null object
# plan_type             2433 non-null object
# connection_type       2433 non-null object
# contract_duration     2433 non-null object
# price_of_plan         928 non-null object
# price_per_mbps        894 non-null object
# dtypes: object(10)
# memory usage: 190.2+ KB

# %% [markdown]
# **Observations:** There are 2433 entries but `price_of_plan` and `price_per_mbps` have far fewer non-null values, indicating significant presence of NaN values.

# %%
df7['max_speed']=pd.to_numeric(df7['max_speed'])
df7['price_of_plan']=pd.to_numeric(df7['price_of_plan'])
# 2381       50.0  Residential  Fixed Broadband   2 year contract
# 2382      100.0  Residential  Fixed Broadband   2 year contract
# 2384      150.0  Residential            Fibre   2 year contract
# 2385      200.0  Residential            Fibre   2 year contract
# 2386      300.0  Residential            Fibre   2 year contract
# 2387      500.0  Residential            Fibre   2 year contract
# 2392       10.0  Residential  Fixed Broadband   2 year contract
# 2393       30.0  Residential  Fixed Broadband   2 year contract
# 2397      100.0  Residential  Fixed Broadband   2 year contract
# 2398      200.0  Residential  Fixed Broadband   2 year contract
# 2399      300.0  Residential  Fixed Broadband   2 year contract
# 2400       25.0  Residential  Fixed Broadband   2 year contract
# 2401       50.0  Residential  Fixed Broadband   2 year contract
# 2402      100.0  Residential  Fixed Broadband   2 year contract
# 2403      150.0  Residential  Fixed Broadband   2 year contract
# 2405      250.0  Residential  Fixed Broadband   2 year contract
# 2406      300.0  Residential  Fixed Broadband   2 year contract
# 2407      500.0  Residential  Fixed Broadband   2 year contract
# 2408     1000.0  Residential  Fixed Broadband   2 year contract
# 2410     1000.0  Residential  Fixed Broadband   2 year contract
# 2413      200.0  Residential            Fibre   2 year contract
# 2414        NaN  Residential            Fibre   2 year contract
# 2415      100.0  Residential            Fibre   2 year contract
# 2416      150.0  Residential            Fibre   2 year contract
# 2417      200.0  Residential            Fibre   2 year contract
# 2418      300.0  Residential            Fibre   2 year contract
# 2419      400.0  Residential            Fibre   2 year contract
# 2420      500.0  Residential            Fibre   2 year contract
# 2421      600.0  Residential            Fibre   2 year contract
# 2424        NaN  Residential  Fixed Broadband   2 year contract
# 2425        NaN  Residential  Fixed Broadband   2 year contract
# 2426        NaN  Residential  Fixed Broadband   2 year contract
# 2427      200.0  Residential  Fixed Broadband   2 year contract
# 2430     2000.0  Residential  Fixed Broadband   2 year contract
#
#       price_of_plan  price_per_mbps
# 2371            NaN             NaN
# 2372            NaN             NaN
# 2378            NaN             NaN
# 2379            NaN             NaN
# 2380            NaN             NaN
# 2381            NaN             NaN
# 2382            NaN             NaN
# 2384            NaN             NaN
# 2385            NaN             NaN
# 2386            NaN             NaN
# 2387            NaN             NaN
# 2392            NaN             NaN
# 2393            NaN             NaN
# 2397            NaN             NaN
# 2398            NaN             NaN
# 2399            NaN             NaN
# 2400            NaN             NaN
# 2401            NaN             NaN
# 2402            NaN             NaN
# 2403            NaN             NaN
# 2405            NaN             NaN
# 2406            NaN             NaN
# 2407            NaN             NaN
# 2408            NaN             NaN
# 2410           59.0             NaN
# 2413            NaN             NaN
# 2414            NaN             NaN
# 2415            NaN             NaN
# 2416            NaN             NaN
# 2417            NaN             NaN
# 2418            NaN             NaN
# 2419            NaN             NaN
# 2420            NaN             NaN
# 2421            NaN             NaN
# 2424            NaN             NaN
# 2425            NaN             NaN
# 2426            NaN             NaN
# 2427            NaN             NaN
# 2430            NaN             NaN

# %%
# write a function to apply across the dataframe
# function to replace each null in price_of_plan and price_per_mbps with the mean of plan
plan_average = df7.groupby('plan').mean()
for i in plan_average.index:
    try:
        df7['price_of_plan'].loc[df7['price_of_plan'].isnull() & df7['plan']==i] = plan_average.loc[i]['price_of_plan']
        df7['price_per_mbps'].loc[df7['price_per_mbps'].isnull() & df7['plan']==i] = plan_average.loc[i]['price_per_mbps']
        df7['max_speed'].loc[df7['max_speed'].isnull() & df7['plan']==i] = plan_average.loc[i]['max_speed']
    except:
        print('Plan {} has no values to fill'.format(i))
df7
# Out:
# c:\users\ian chong\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#
# c:\users\ian chong\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:202: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         month date_of_retrieval_    operator                   plan  \
# 0     2013-03          14/3/2013     Singnet          Sn 6mbps adsl
# 1     2013-03          14/3/2013     Singnet         Sn 10mbps adsl
# 2     2013-03          14/3/2013     Singnet         Sn 15mbps adsl
# 3     2013-03          14/3/2013     Singnet  Sn 150mbps fibre plan
# 4     2013-03          14/3/2013     Singnet  Sn 200mbps fibre plan
# ...       ...                ...         ...                    ...
# 2428  2016-06           3/6/2016  MyRepublic            Ultra 1gbps
# 2429  2016-06           3/6/2016  MyRepublic            Gamer 1gbps
# 2430  2016-06           3/6/2016  MyRepublic     Ultra 2gbps bundle
# 2431  2016-06           3/6/2016  MyRepublic       Ultra 1 + 1 gbps
# 2432  2016-06           3/6/2016  MyRepublic       Gamer 1 + 1 gpbs
#
#       max_speed    plan_type  connection_type contract_duration  \
# 0           6.0  Residential             ADSL   2 year contract
# 1          10.0  Residential             ADSL   2 year contract
# 2          15.0  Residential             ADSL   2 year contract
# 3         150.0  Residential            Fibre   2 year contract
# 4         200.0  Residential            Fibre   2 year contract
# ...         ...          ...              ...               ...
# 2428     1000.0  Residential  Fixed Broadband   2 year contract
# 2429     1000.0  Residential  Fixed Broadband   2 year contract
# 2430     2000.0  Residential  Fixed Broadband   2 year contract
# 2431     2000.0  Residential  Fixed Broadband   2 year contract
# 2432     2000.0  Residential  Fixed Broadband   2 year contract
#
#       price_of_plan  price_per_mbps
# 0             29.90            4.99
# 1             31.90            3.19
# 2             36.90            2.46
# 3             49.90            0.33
# 4             59.90            0.30
# ...             ...             ...
# 2428          49.99            0.05
# 2429          59.99            0.06
# 2430            NaN             NaN
# 2431          59.99            0.03
# 2432          69.99            0.03
#
# [2433 rows x 10 columns]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2433 entries, 0 to 2432
# Data columns (total 10 columns):
# month                 2433 non-null object
# date_of_retrieval_    2433 non-null object
# operator              2433 non-null object
# plan                  2433 non-null object
# max_speed             2243 non-null float64
# plan_type             2433 non-null object
# connection_type       2433 non-null object
# contract_duration     2433 non-null object
# price_of_plan         928 non-null float64
# price_per_mbps        894 non-null float64
# dtypes: float64(3), object(7)
# memory usage: 190.2+ KB

# %% [markdown]
# The dataset still has many `NaN` values. We will refrain from filling in with broad averages since this will distort the data too much.

# %%
fig = px.scatter(df7, 
                 x="max_speed", 
                 y="price_of_plan", 
                 color="operator",
                 hover_name='month',
                 template='seaborn',
                 marginal_y='histogram',marginal_x='rug')
fig.show()
# sns.scatterplot(data=df7,x='max_speed',y='price_of_plan',hue='operator').set_title('Singapore Broadband Plans')
# plt.xlabel('Max Speed (MBPS)')
# plt.ylabel('Plan Price (SGD)')
# plt.show()

# %%
sns.distplot(df7['price_per_mbps'].dropna(),bins=15).set_title('Histogram of Plans by SGD/Mbps')
plt.xlabel('SGD/Mbps')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data=df7,
            x='operator',
            y='price_per_mbps',
            notch=True).set_title('Singapore Telco Pricing Boxplot')
plt.xlabel('Telco Operator')
plt.ylabel('SGD/Mbps')
plt.show()

# %%
sns.boxplot(data=df7,
            x='connection_type',
            y='price_per_mbps',
            notch=True).set_title('Singapore Telco Pricing Boxplot')
plt.xlabel('Contract Type')
plt.ylabel('SGD/Mbps')
plt.show()

# %% [markdown]
# At first glance, it would seem that Singtel is lagging behind the pack in terms of value of money.
#
# However, we note that ADSL connections are signficantly more expensive than Fibre and Fixed Broadband, which tend be more common nowadays.
#
# Analyzing just the Fibre segment...

# %%
sns.boxplot(data=df7[df7['connection_type']=='Fibre'],
            x='operator',
            y='price_per_mbps',
            notch=True).set_title('Singapore Telco Pricing Boxplot (Fibre only)')
# Out:
# Text(0.5, 1.0, 'Singapore Telco Pricing Boxplot (Fibre only)')

# %% [markdown]
# We find that the reverse is true. Hence, Singnet's legacy offerings of ADSL services was skewing the data.

# %%
df7[df7['connection_type'] == 'Fibre'].describe()
# Out:
#          max_speed  price_of_plan  price_per_mbps
# count   839.000000     378.000000      375.000000
# mean    494.994041     101.501455        0.243253
# std     449.547605     105.737525        0.159188
# min     100.000000      39.900000        0.030000
# 25%     200.000000      50.000000        0.120000
# 50%     300.000000      62.900000        0.200000
# 75%     600.000000      89.950000        0.330000
# max    2000.000000     499.950000        0.630000

# %% [markdown]
# ## Analysis
#
# At an average of SGD 0.24 per mbps per month, Singapore telcos offer good value for money on a global scale, beating even the G10.
#
# As can be seen from the histogram, most of the plans offered speeds at well below a dollar per mbps.
#
# After filtering out ADSL plans (which are legacy), we find that Singtel offers the best value for money in terms of sheer mbps.
#
# However, an important caveat for Dataset 7 was the signficant presence of `NaN` values.
#
# We tried filling in the values using averages of the appropriate plan to no avail.
#
# The rows with `NaN` values belonged to plans which had no historical data, and therefore we could not fill in the missing values.

# %% [markdown]
# # MySQL

# %%
user, pw, host, db = 'root','(Hl2freak)','127.0.0.1','ca2ian'
cnx = mysql.connector.connect(user=user,
                            password=pw,
                            host=host,
                            database=db)
cursor = cnx.cursor()

# %%
query_for_creating_table = ("CREATE TABLE `fixed-broadband-plans-and-prices` (`cea_salesperson_id` int(11) NOT NULL AUTO_INCREMENT, `salesperson_name`varchar(100) NOT NULL, `registration_no` varchar(50), `registration_start_date` date NOT NULL, `registration_end_date` date NOT NULL, `estate_agent_name` varchar(100) NOT NULL, `estate_agent_license_no` varchar(50) NOT NULL, PRIMARY KEY (`cea_salesperson_id`)) ENGINE=InnoDB")

try:
    print("Executing CREATE TABLE command")
    cursor.execute(query_for_creating_table)
    cnx.commit()
    print("Table created!")
    
except:
    print("Unexpected error:", sys.exc_info()[0])
    
finally:
    cursor.close()
    cnx.close()
